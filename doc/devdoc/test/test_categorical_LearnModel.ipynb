# %%
import sys
sys.path.append('..')

# %%
from bayesml import categorical
import numpy as np

# %%
gm = categorical.GenModel()
lm = categorical.LearnModel(d=3)

# %%
X = gm.gen_sample(sample_size=20)

# %%
lm.get_h0_params()
# Out:
# {'h0_alpha_vec': array([5., 5., 5.])}

# %%
lm.update_posterior(X=np.array([23,2,43])) # 更新がうまくできていることの確認
lm.get_hn_params()
# Out:
# {'hn_alpha_vec': array([28.,  7., 48.])}

# %%
lm.estimate_params()
# Out:
# array([0.3373494 , 0.08433735, 0.57831325])

# %%
lm.visualize_posterior()
