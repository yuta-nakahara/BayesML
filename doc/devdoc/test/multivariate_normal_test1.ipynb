# %%
import numpy as np
import _multivariatenormal

# %%
model1 = _multivariatenormal.GenModel(D=1,mu=0,sigma=2.0,precision=0.5,h_mu=1,h_kappa=1.0,h_nu=2.0,h_V=1)
model1.gen_params()
model1.get_params()
# Out:
# {'D': 1,
#  'mu': -22.349294888615372,
#  'sigma': 14.922021373115353,
#  'precision': 0.06701504943570688}

# %%
model1.visualize_model()
# Out:
# normal
# mean:-22.349294888615372
# cov:14.922021373115353
# wishart
# mean:2.0
# normal(prior distribution)
# mean:1.0
# cov:14.922021373115353

# %%
x1 = model1.gen_sample(3)
print(x1)
# Out:
# [-40.6825831  -48.21424828 -35.57038348]

# %%
x2 = model1.gen_sample(3)
print(x2)
# Out:
# [-29.80257858 -25.99323225 -35.4692531 ]

# %%
model = _multivariatenormal.LearnModel(D=1,h0_mu=1.0,h0_kappa=1.0,h0_nu=2.0,h0_V=1.0)

# %%
model.pred_and_update(x1)
# Out:
# 1.0

# %%
model.pred_and_update(x2)
# Out:
# array([-30.11680371])

# %%
model.visualize_posterior(n=6)
# Out:
# 107.33074810557784

# %%
model.get_hn_params()
# Out:
# {'hn_mu': array([-43.15466999]),
#  'hn_kappa': 7.0,
#  'hn_nu': 8.0,
#  'hn_V': array([[0.00099825]])}

# %%
model.reset_hn_params()
model.get_hn_params()
# Out:
# {'hn_mu': 1.0, 'hn_kappa': 1.0, 'hn_nu': 2.0, 'hn_V': 1.0}
