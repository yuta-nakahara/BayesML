# %%
import normal
import numpy as np

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
X=np.linspace(-10,10,100)
norm_pdf=norm.pdf(X)
plt.plot(X,norm_pdf)

# %%
model = normal.GenModel()
model.visualize_model()
# Out:
# mu:0.0
# X:[ 0.37855313 -0.17663559  0.79246009 -0.96355534 -0.24391577  0.90536628
#   0.97448244 -1.63713265  0.26251627 -0.86358358 -1.60740887  0.51653368
#  -1.58646152 -0.80963394 -0.00569327 -0.22380874 -1.64790884 -0.96561963
#   0.16582421  0.72065081  0.98565645 -1.23129297  0.0710042  -0.98019702
#  -0.37490784 -0.77824479  0.98501955 -2.12714991 -1.1296167   0.92445986
#   0.72507288 -0.51272501  0.76068287  0.77299041  1.23503539  1.16740551
#   1.4287611  -0.99598935  0.98252589 -0.59291443  0.61413241  1.38475814
#  -0.6349245  -1.40051781  0.0399183  -0.51875784 -1.10890849  1.18493985
#  -0.25016983  0.59932677 -0.39972238  1.20069573 -2.00586556 -2.34937525
#   1.06515355  0.80100483  1.21297847  2.11450592  0.53283081  0.37571531
#   0.55857188  0.24361131 -0.32681526 -0.72785668  0.23481991 -0.14078283
#  -0.41158432  0.57347735 -0.16404172 -0.03893142  0.35802076 -0.62545944
#   1.47597866  0.86309827  0.04517299  0.63799757  1.0696532  -1.19118503
#   0.25585736 -0.28790367  0.67364318 -0.63178404 -0.07554158  1.12433952
#  -0.0706027  -0.3866585   1.42734344 -0.7601803   0.29340245  1.98755872
#   0.40139355 -0.81499024  1.14094097 -0.22541435  1.13211449  1.2697519
#  -0.63346052  0.27515819  0.80994021  0.12142691]
